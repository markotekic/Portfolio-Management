# %% [markdown]
# ### This Workbook demonstrates how to download the last 20 years worth of share price data for all Wilshire5000 Index constituents.

# %% [markdown]
# #### Import Libraries

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np
# Allows for further data manipulation and analysis
import pandas as pd
# Download time series data for S&P500 or Wilshire5000 via alpha vantage API
from alpha_vantage.timeseries import TimeSeries

import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates #styling dates
# %matplotlib inline

import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance
import time

#getting data from directory
import os
from os import listdir
from os.path import isfile, join

# API key from alpha vantage
key = open(r"C:/Users/User/Documents/PM Tools/US Share Market Data/Alpha_vantage_api_key.txt").read()

# %% [markdown]
# #### List of Shares Not Downloaded

# %%
shares_not_downloaded = [] # create list of shares that failed to download
missing_shares = [] # place shares that didn't download into a new list for later use

# %% [markdown]
# #### Save Data to CSV

# %%
# download the last 20 years of daily adjusted prices for Wilshire5000 constituents
def save_shares_data_to_csv(folder, ticker):
    try:
        print("Get data for:", ticker)
        api_call = TimeSeries(key, output_format='pandas') #api call (alpha vantage)
        df = api_call.get_daily_adjusted(ticker, outputsize='full') # get daily adjusted prices and save to data frame
        time.sleep(1) #pause for 1 second between calls to cut down on missing data 
        df[0].to_csv(folder + ticker + ".csv") # save ticker data from df to csv
        # index at 0 returns the dataframe. Otherwise, it would output a tuple and an error.
    except Exception as ex:
        shares_not_downloaded.append(ticker) #append list of shares not downloaded
        print("Couldn't get data for:", ticker)

# %% [markdown]
# #### Return Dataframe from CSV

# %%
def get_shares_df_from_csv(folder, ticker):
    try:  
        df = pd.read_csv(folder + ticker + ".csv") 
    except FileNotFoundError:
        print("File doesn't exist.")
    else:
        return df

# %% [markdown]
# #### Return a Named Column Data from CSV

# %%
def get_column_from_csv(file, column_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File doesn't exist.")
    else:
        return df[column_name]

# %% [markdown]
# #### Test receiving Tickers List

# %%
# loading wilshire 5000 tickers from csv
# search online for updated tickers list for Wilshire5000 or S&P500 indicies 
tickers = get_column_from_csv(r"C:/Users/User/Documents/PM Tools/US Share Market Data/wilshire5000_tickers.csv", "Ticker")
tickers
# Out:
# 0          A
# 1         AA
# 2        AAC
# 3        AAL
# 4       AAME
#         ...
# 3213    PFLT
# 3214     PRT
# 3215    PSEC
# 3216     SBR
# 3217    SUNS
# Name: Ticker, Length: 3218, dtype: object

# %% [markdown]
# #### TEST: Get 20 years of data for the first 10 shares from tickers list

# %%
# define folder path where all the csv files will be saved to.
folder = (r"C:/Users/User/Documents/PM Tools/US Share Market Data/Wilshire5000/")
for x in range(10):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
# Out:
# Get data for: A
# Get data for: AA
# Get data for: AAC
# Get data for: AAL
# Get data for: AAME
# Get data for: AAN
# Get data for: AAOI
# Get data for: AAON
# Get data for: AAP
# Get data for: AAPL
# Finished

# %% [markdown]
# #### Download all Wilshire5000 Shares in Blocks
#
# Code bellow assumes free API access with 500 max. calls per day. Whole data set for Wilshire5000 or S&P500 can be downloaded with a single function call and premium API key.
# When using a premium API key, change final range in "for loop" from 500 to the object lenght of tickers list (in my case that is 3218).

# %%
for x in range(10, 500):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: AAT
# Get data for: AAWW
# Get data for: ABBV
# Get data for: ABC
# Get data for: ABCB
# Get data for: ABEO
# Get data for: ABG
# Get data for: ABIO
# Get data for: ABM
# Get data for: ABMD
# Get data for: ABR
# Get data for: ABT
# Get data for: ABTX
# Get data for: AC
# Get data for: ACA
# Get data for: ACAD
# Get data for: ACBI
# Get data for: ACC
# Get data for: ACCO
# Get data for: ACER
# Get data for: ACGL
# Get data for: ACHC
# Get data for: ACHN
# Get data for: ACHV
# Get data for: ACIA
# Get data for: ACIW
# Get data for: ACLS
# Get data for: ACM
# Get data for: ACMR
# Get data for: ACN
# Get data for: ACNB
# Get data for: ACOR
# Get data for: ACRE
# Get data for: ACRS
# Get data for: ACRX
# Get data for: ACTG
# Get data for: ACU
# Get data for: ADBE
# Get data for: ADC
# Get data for: ADES
# Get data for: ADI
# Get data for: ADM
# Get data for: ADMA
# Get data for: ADMP
# Get data for: ADMS
# Get data for: ADNT
# Get data for: ADP
# Get data for: ADSK
# Get data for: ADT
# Get data for: ADTN
# Get data for: ADUS
# Get data for: ADVM
# Get data for: ADXS
# Get data for: AE
# Get data for: AEE
# Get data for: AEGN
# Get data for: AEHR
# Get data for: AEIS
# Get data for: AEL
# Get data for: AEMD
# Get data for: AEO
# Get data for: AEP
# Get data for: AERI
# Get data for: AES
# Get data for: AEY
# Get data for: AFG
# Get data for: AFI
# Couldn't get data for: AFI
# Get data for: AFL
# Get data for: AGCO
# Get data for: AGE
# Get data for: AGEN
# Get data for: AGFS
# Get data for: AGIO
# Get data for: AGLE
# Get data for: AGM
# Get data for: AGMA
# Couldn't get data for: AGMA
# Get data for: AGNC
# Get data for: AGO
# Get data for: AGR
# Get data for: AGRX
# Get data for: AGS
# Get data for: AGTC
# Get data for: AGX
# Get data for: AGYS
# Get data for: AHC
# Couldn't get data for: AHC
# Get data for: AHH
# Get data for: AHT
# Get data for: AIG
# Get data for: AIMC
# Get data for: AIMT
# Get data for: AIN
# Get data for: AINC
# Get data for: AIR
# Get data for: AIRG
# Get data for: AIRI
# Get data for: AIRT
# Get data for: AIT
# Get data for: AIV
# Get data for: AIZ
# Get data for: AJG
# Get data for: AJRD
# Get data for: AJX
# Get data for: AKAM
# Get data for: AKBA
# Get data for: AKCA
# Get data for: AKR
# Get data for: AKTS
# Get data for: AL
# Get data for: ALB
# Get data for: ALBO
# Get data for: ALCO
# Get data for: ALDX
# Get data for: ALE
# Get data for: ALEC
# Get data for: ALEX
# Get data for: ALG
# Get data for: ALGN
# Get data for: ALGT
# Get data for: ALIM
# Get data for: ALJJ
# Get data for: ALK
# Get data for: ALKS
# Get data for: ALL
# Get data for: ALLE
# Get data for: ALLK
# Get data for: ALLO
# Get data for: ALLY
# Get data for: ALNA
# Couldn't get data for: ALNA
# Get data for: ALNY
# Get data for: ALOT
# Get data for: ALPN
# Get data for: ALRM
# Get data for: ALSK
# Get data for: ALSN
# Get data for: ALT
# Get data for: ALTR
# Get data for: ALV
# Get data for: ALX
# Get data for: ALXN
# Get data for: AM
# Get data for: AMAL
# Get data for: AMAT
# Get data for: AMBC
# Get data for: AMC
# Get data for: AMCR
# Get data for: AMCX
# Get data for: AMD
# Get data for: AME
# Get data for: AMED
# Get data for: AMEH
# Get data for: AMG
# Get data for: AMGN
# Get data for: AMH
# Get data for: AMKR
# Get data for: AMN
# Get data for: AMNB
# Get data for: AMOT
# Get data for: AMP
# Get data for: AMPE
# Get data for: AMPH
# Get data for: AMR
# Get data for: AMRB
# Get data for: AMRC
# Get data for: AMRK
# Get data for: AMRS
# Get data for: AMRX
# Get data for: AMS
# Get data for: AMSC
# Get data for: AMSF
# Get data for: AMSWA
# Get data for: AMT
# Get data for: AMTD
# Get data for: AMTX
# Get data for: AMWD
# Get data for: AMZN
# Get data for: AN
# Get data for: ANAB
# Get data for: ANAT
# Get data for: ANDE
# Get data for: ANET
# Get data for: ANF
# Get data for: ANGI
# Get data for: ANGO
# Get data for: ANH
# Get data for: ANIK
# Get data for: ANIP
# Get data for: ANIX
# Couldn't get data for: ANIX
# Get data for: ANSS
# Get data for: ANTM
# Couldn't get data for: ANTM
# Get data for: AON
# Get data for: AOS
# Get data for: AOSL
# Get data for: AP
# Get data for: APA
# Get data for: APAM
# Get data for: APD
# Get data for: APDN
# Get data for: APEI
# Get data for: APEN
# Get data for: APEX
# Get data for: APH
# Get data for: APLE
# Get data for: APLS
# Get data for: APOG
# Get data for: APPF
# Get data for: APPN
# Get data for: APPS
# Get data for: APRN
# Get data for: APT
# Get data for: APTS
# Get data for: APTV
# Get data for: APVO
# Get data for: APYX
# Get data for: AQB
# Get data for: AQMS
# Get data for: AQUA
# Get data for: AR
# Get data for: ARA
# Couldn't get data for: ARA
# Get data for: ARAV
# Get data for: ARAY
# Get data for: ARC
# Get data for: ARCB
# Get data for: ARCH
# Get data for: ARDX
# Get data for: ARE
# Get data for: ARES
# Get data for: ARGO
# Get data for: ARI
# Get data for: ARKR
# Get data for: ARL
# Get data for: ARLO
# Get data for: ARMK
# Get data for: ARMP
# Get data for: ARNA
# Get data for: ARNC
# Get data for: AROC
# Get data for: AROW
# Get data for: ARPO
# Get data for: ARR
# Get data for: ARTNA
# Get data for: ARTW
# Get data for: ARVN
# Get data for: ARW
# Get data for: ARWR
# Get data for: ASB
# Get data for: ASGN
# Get data for: ASH
# Get data for: ASIX
# Get data for: ASMB
# Get data for: ASPN
# Get data for: ASPS
# Get data for: ASPU
# Get data for: ASRT
# Get data for: ASRV
# Get data for: ASTC
# Get data for: ASTE
# Get data for: ASUR
# Get data for: ASYS
# Get data for: ATEC
# Get data for: ATEN
# Get data for: ATEX
# Get data for: ATGE
# Get data for: ATH
# Get data for: ATHX
# Get data for: ATI
# Get data for: ATKR
# Get data for: ATLC
# Get data for: ATLO
# Get data for: ATNI
# Get data for: ATNM
# Get data for: ATNX
# Get data for: ATO
# Get data for: ATOS
# Get data for: ATR
# Get data for: ATRA
# Get data for: ATRC
# Get data for: ATRI
# Get data for: ATRO
# Get data for: ATRS
# Get data for: ATSG
# Get data for: ATUS
# Get data for: ATVI
# Get data for: AUB
# Get data for: AUBN
# Get data for: AUMN
# Get data for: AUTO
# Get data for: AVA
# Get data for: AVAV
# Get data for: AVB
# Get data for: AVD
# Get data for: AVEO
# Get data for: AVGO
# Get data for: AVGR
# Get data for: AVID
# Get data for: AVLR
# Get data for: AVNS
# Get data for: AVNW
# Get data for: AVRO
# Get data for: AVT
# Get data for: AVTR
# Get data for: AVXL
# Get data for: AVY
# Get data for: AVYA
# Get data for: AWI
# Get data for: AWK
# Get data for: AWR
# Get data for: AWRE
# Get data for: AX
# Get data for: AXAS
# Get data for: AXDX
# Get data for: AXGN
# Get data for: AXL
# Get data for: AXNX
# Get data for: AXP
# Get data for: AXR
# Get data for: AXS
# Get data for: AXSM
# Get data for: AXTA
# Get data for: AXTI
# Get data for: AYI
# Get data for: AYX
# Get data for: AZO
# Get data for: AZPN
# Get data for: AZZ
# Get data for: B
# Get data for: BA
# Get data for: BAC
# Get data for: BAH
# Get data for: BANC
# Get data for: BAND
# Get data for: BANF
# Get data for: BANR
# Get data for: BASI
# Get data for: BATRA
# Get data for: BATRK
# Get data for: BAX
# Get data for: BBBY
# Get data for: BBCP
# Get data for: BBGI
# Get data for: BBSI
# Get data for: BBW
# Get data for: BBY
# Get data for: BC
# Get data for: BCBP
# Get data for: BCC
# Get data for: BCLI
# Get data for: BCO
# Get data for: BCOR
# Get data for: BCOV
# Get data for: BCPC
# Get data for: BCRX
# Get data for: BDC
# Get data for: BDGE
# Get data for: BDL
# Get data for: BDN
# Get data for: BDSI
# Get data for: BDX
# Get data for: BE
# Get data for: BEAT
# Get data for: BECN
# Get data for: BELFA
# Get data for: BELFB
# Get data for: BEN
# Get data for: BERY
# Get data for: BFA
# Get data for: BFAM
# Get data for: BFB
# Couldn't get data for: BFB
# Get data for: BFIN
# Get data for: BFS
# Get data for: BFST
# Get data for: BG
# Get data for: BGCP
# Get data for: BGFV
# Get data for: BGS
# Get data for: BGSF
# Get data for: BH
# Get data for: BHB
# Get data for: BHE
# Get data for: BHF
# Get data for: BHLB
# Get data for: BHR
# Get data for: BHVN
# Get data for: BIG
# Get data for: BIIB
# Get data for: BIO
# Get data for: BIOC
# Get data for: BIOL
# Get data for: BIOS
# Get data for: BJ
# Get data for: BJRI
# Get data for: BK
# Get data for: BKD
# Get data for: BKE
# Get data for: BKH
# Get data for: BKI
# Get data for: BKNG
# Get data for: BKSC
# Get data for: BKTI
# Get data for: BKU
# Get data for: BL
# Get data for: BLBD
# Get data for: BLCM
# Get data for: BLD
# Get data for: BLDR
# Get data for: BLFS
# Get data for: BLK
# Get data for: BLKB
# Get data for: BLL
# Couldn't get data for: BLL
# Get data for: BLMN
# Get data for: BLUE
# Get data for: BMCH
# Get data for: BMI
# Get data for: BMRC
# Get data for: BMRN
# Get data for: BMTC
# Get data for: BMY
# Get data for: BNED
# Get data for: BNFT
# Get data for: BOCH
# Get data for: BOH
# Get data for: BOKF
# Get data for: BOMN
# Couldn't get data for: BOMN
# Get data for: BOOM
# Get data for: BOOT
# Get data for: BOTJ
# Get data for: BOX
# Get data for: BPFH
# Get data for: BPMC
# Get data for: BPOP
# Get data for: BPRN
# Get data for: BPTH
# Get data for: BR
# Get data for: BRC
# Get data for: BRG
# Couldn't get data for: BRG
# Get data for: BRID
# Get data for: BRKB
# Get data for: BRKL
# Get data for: BRKR
# Get data for: BRN
# Get data for: BRO
# Get data for: BRT
# Get data for: BRX
# Get data for: BRY
# Get data for: BSET
# Get data for: BSGM
# Get data for: BSQR
# Get data for: BSRR
# Get data for: BSTC
# Get data for: BSX
# Get data for: BTN
# Get data for: BTU
# Get data for: BURL
# Get data for: BUSE
# Get data for: BV
# Get data for: BW
# Get data for: BWA
# Get data for: BWB
# Get data for: BWEN
# Get data for: BWFG
# Get data for: BWXT
# Get data for: BXC
# Get data for: BXMT
# Get data for: BXP
# Get data for: BY
# Get data for: BYD
# Get data for: BYFC
# Get data for: BYND
# Get data for: BZH
# Get data for: C
# Get data for: CABO
# Get data for: CAC
# Get data for: CACC
# Get data for: CACI
# Get data for: CADE
# Get data for: CAG
# Get data for: CAH
# Get data for: CAI
# Couldn't get data for: CAI
# Get data for: CAKE
# Get data for: CAL
# Get data for: CALA
# Get data for: CALM
# Get data for: CALX
# Get data for: CAMP
# Get data for: CAPR
# Get data for: CAR
# Get data for: CARA
# Get data for: CARE
# Get data for: CARG
# Get data for: CARS
# Get data for: CASA
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI']

# %%
for x in range(500, 1000):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: CASH
# Get data for: CASI
# Get data for: CASS
# Get data for: CASY
# Get data for: CAT
# Get data for: CATC
# Get data for: CATM
# Get data for: CATO
# Get data for: CATY
# Get data for: CB
# Get data for: CBAN
# Get data for: CBAY
# Get data for: CBB
# Couldn't get data for: CBB
# Get data for: CBFV
# Get data for: CBIO
# Get data for: CBL
# Get data for: CBMG
# Get data for: CBOE
# Get data for: CBRE
# Get data for: CBRL
# Get data for: CBSH
# Get data for: CBT
# Get data for: CBTX
# Couldn't get data for: CBTX
# Get data for: CBU
# Get data for: CBZ
# Get data for: CC
# Get data for: CCBG
# Get data for: CCF
# Get data for: CCI
# Get data for: CCK
# Get data for: CCL
# Get data for: CCMP
# Get data for: CCNE
# Get data for: CCO
# Get data for: CCOI
# Get data for: CCRN
# Get data for: CCS
# Get data for: CCXI
# Get data for: CDAY
# Get data for: CDE
# Get data for: CDEV
# Couldn't get data for: CDEV
# Get data for: CDK
# Get data for: CDLX
# Get data for: CDMO
# Get data for: CDNA
# Get data for: CDNS
# Get data for: CDR
# Couldn't get data for: CDR
# Get data for: CDTX
# Get data for: CDW
# Get data for: CDXC
# Get data for: CDXS
# Get data for: CDZI
# Get data for: CE
# Get data for: CECE
# Couldn't get data for: CECE
# Get data for: CECO
# Get data for: CEI
# Get data for: CEIX
# Get data for: CELC
# Get data for: CELH
# Get data for: CEMI
# Get data for: CENT
# Get data for: CENTA
# Get data for: CENX
# Get data for: CERN
# Get data for: CERS
# Get data for: CETX
# Get data for: CEVA
# Get data for: CF
# Get data for: CFBK
# Get data for: CFFI
# Get data for: CFFN
# Get data for: CFG
# Get data for: CFMS
# Get data for: CFR
# Get data for: CGIX
# Get data for: CGNX
# Get data for: CHCI
# Get data for: CHCO
# Get data for: CHCT
# Get data for: CHD
# Get data for: CHDN
# Get data for: CHE
# Get data for: CHEF
# Get data for: CHGG
# Get data for: CHH
# Get data for: CHK
# Get data for: CHMA
# Get data for: CHMG
# Get data for: CHMI
# Get data for: CHRS
# Get data for: CHRW
# Get data for: CHS
# Get data for: CHTR
# Get data for: CHUY
# Get data for: CI
# Get data for: CIA
# Get data for: CIDM
# Get data for: CIEN
# Get data for: CIM
# Get data for: CINF
# Get data for: CIO
# Get data for: CIR
# Get data for: CIT
# Get data for: CIVB
# Get data for: CIX
# Get data for: CIZN
# Get data for: CKH
# Get data for: CKX
# Get data for: CL
# Get data for: CLAR
# Get data for: CLB
# Get data for: CLBK
# Get data for: CLBS
# Couldn't get data for: CLBS
# Get data for: CLCT
# Get data for: CLDR
# Get data for: CLDT
# Get data for: CLDX
# Get data for: CLF
# Get data for: CLFD
# Get data for: CLGX
# Get data for: CLH
# Get data for: CLIR
# Get data for: CLNE
# Get data for: CLPR
# Get data for: CLR
# Couldn't get data for: CLR
# Get data for: CLRB
# Get data for: CLRO
# Get data for: CLSN
# Couldn't get data for: CLSN
# Get data for: CLVS
# Couldn't get data for: CLVS
# Get data for: CLW
# Get data for: CLX
# Get data for: CLXT
# Get data for: CMA
# Get data for: CMC
# Get data for: CMCO
# Get data for: CMCSA
# Get data for: CMCT
# Get data for: CMD
# Couldn't get data for: CMD
# Get data for: CME
# Get data for: CMG
# Get data for: CMI
# Get data for: CMO
# Couldn't get data for: CMO
# Get data for: CMP
# Get data for: CMRX
# Get data for: CMS
# Get data for: CMT
# Get data for: CMTL
# Get data for: CNA
# Get data for: CNBKA
# Get data for: CNC
# Get data for: CNCE
# Get data for: CNDT
# Get data for: CNFR
# Get data for: CNK
# Get data for: CNMD
# Get data for: CNNE
# Get data for: CNO
# Get data for: CNOB
# Get data for: CNP
# Get data for: CNR
# Couldn't get data for: CNR
# Get data for: CNS
# Get data for: CNSL
# Get data for: CNTY
# Get data for: CNX
# Get data for: CNXN
# Get data for: CODA
# Get data for: COF
# Get data for: COG
# Couldn't get data for: COG
# Get data for: COHN
# Get data for: COHR
# Get data for: COHU
# Get data for: COKE
# Get data for: COLB
# Get data for: COLD
# Get data for: COLL
# Get data for: COLM
# Get data for: COMM
# Get data for: CONE
# Get data for: CONN
# Get data for: COO
# Get data for: COOP
# Get data for: COP
# Get data for: COR
# Get data for: CORE
# Get data for: CORR
# Get data for: CORT
# Get data for: COST
# Get data for: COTY
# Get data for: COUP
# Get data for: COWN
# Get data for: CPB
# Get data for: CPE
# Get data for: CPF
# Get data for: CPHC
# Get data for: CPIX
# Get data for: CPK
# Get data for: CPLG
# Get data for: CPRI
# Get data for: CPRT
# Get data for: CPRX
# Get data for: CPS
# Get data for: CPSH
# Get data for: CPSI
# Get data for: CPSS
# Get data for: CPT
# Get data for: CR
# Get data for: CRAI
# Get data for: CRBP
# Get data for: CRC
# Get data for: CRDA
# Get data for: CRDB
# Couldn't get data for: CRDB
# Get data for: CREE
# Get data for: CRI
# Get data for: CRIS
# Get data for: CRK
# Get data for: CRL
# Get data for: CRM
# Get data for: CRMD
# Get data for: CRMT
# Get data for: CRNX
# Get data for: CROX
# Get data for: CRS
# Get data for: CRTX
# Get data for: CRUS
# Get data for: CRVL
# Get data for: CRVS
# Get data for: CRWS
# Get data for: CSCO
# Get data for: CSGP
# Get data for: CSGS
# Get data for: CSII
# Get data for: CSL
# Get data for: CSLT
# Get data for: CSOD
# Get data for: CSPI
# Get data for: CSTR
# Get data for: CSV
# Get data for: CSWI
# Get data for: CSX
# Get data for: CTAS
# Get data for: CTB
# Get data for: CTBI
# Get data for: CTG
# Get data for: CTHR
# Get data for: CTIB
# Get data for: CTIC
# Get data for: CTLT
# Get data for: CTMX
# Get data for: CTO
# Get data for: CTRA
# Get data for: CTRE
# Get data for: CTRN
# Get data for: CTS
# Get data for: CTSH
# Get data for: CTSO
# Get data for: CTT
# Couldn't get data for: CTT
# Get data for: CTVA
# Get data for: CTXS
# Get data for: CUB
# Get data for: CUBE
# Get data for: CUBI
# Get data for: CUE
# Get data for: CULP
# Get data for: CURO
# Get data for: CUTR
# Get data for: CUZ
# Get data for: CVA
# Get data for: CVBF
# Get data for: CVCO
# Get data for: CVCY
# Get data for: CVET
# Get data for: CVGI
# Get data for: CVGW
# Get data for: CVI
# Get data for: CVLT
# Get data for: CVLY
# Get data for: CVM
# Get data for: CVNA
# Get data for: CVR
# Get data for: CVS
# Get data for: CVU
# Get data for: CVV
# Get data for: CVX
# Get data for: CW
# Get data for: CWBC
# Get data for: CWBR
# Get data for: CWEN
# Get data for: CWENA
# Get data for: CWH
# Get data for: CWST
# Get data for: CWT
# Get data for: CXO
# Couldn't get data for: CXO
# Get data for: CXP
# Get data for: CXW
# Get data for: CYAN
# Get data for: CYBE
# Get data for: CYCC
# Get data for: CYCN
# Get data for: CYH
# Get data for: CYRX
# Get data for: CYTK
# Get data for: CYTR
# Couldn't get data for: CYTR
# Get data for: CZNC
# Get data for: CZR
# Get data for: CZWI
# Get data for: D
# Get data for: DAIO
# Get data for: DAKT
# Get data for: DAL
# Get data for: DAN
# Get data for: DAR
# Get data for: DARE
# Get data for: DAVE
# Get data for: DBD
# Get data for: DBI
# Get data for: DBX
# Get data for: DCI
# Get data for: DCO
# Get data for: DCOM
# Get data for: DCPH
# Get data for: DD
# Get data for: DDD
# Get data for: DDS
# Get data for: DE
# Get data for: DEA
# Get data for: DECK
# Get data for: DEI
# Get data for: DELL
# Get data for: DENN
# Get data for: DERM
# Get data for: DFIN
# Get data for: DFS
# Get data for: DG
# Get data for: DGICA
# Get data for: DGII
# Get data for: DGLY
# Get data for: DGX
# Get data for: DHI
# Get data for: DHIL
# Get data for: DHR
# Get data for: DHX
# Get data for: DIN
# Get data for: DIOD
# Get data for: DIS
# Get data for: DISCK
# Get data for: DISH
# Get data for: DIT
# Get data for: DJCO
# Get data for: DK
# Get data for: DKS
# Get data for: DLA
# Get data for: DLB
# Get data for: DLHC
# Get data for: DLR
# Get data for: DLTH
# Get data for: DLTR
# Get data for: DLX
# Get data for: DMRC
# Get data for: DNKN
# Get data for: DNLI
# Get data for: DNOW
# Get data for: DO
# Get data for: DOC
# Get data for: DOCU
# Get data for: DOMO
# Get data for: DOOR
# Get data for: DORM
# Get data for: DOV
# Get data for: DOW
# Get data for: DPZ
# Get data for: DRE
# Couldn't get data for: DRE
# Get data for: DRH
# Get data for: DRI
# Get data for: DRNA
# Get data for: DRQ
# Get data for: DRRX
# Get data for: DS
# Get data for: DSKE
# Get data for: DSPG
# Get data for: DSS
# Get data for: DTE
# Get data for: DUK
# Get data for: DVA
# Get data for: DVAX
# Get data for: DVD
# Get data for: DVN
# Get data for: DWSN
# Get data for: DX
# Get data for: DXC
# Get data for: DXCM
# Get data for: DXLG
# Get data for: DXPE
# Get data for: DXYN
# Get data for: DY
# Get data for: DYAI
# Get data for: DZSI
# Get data for: EA
# Get data for: EAF
# Get data for: EARN
# Get data for: EAT
# Get data for: EB
# Get data for: EBAY
# Get data for: EBF
# Get data for: EBIX
# Get data for: EBMT
# Get data for: EBS
# Get data for: EBSB
# Get data for: EBTC
# Get data for: ECHO
# Get data for: ECL
# Get data for: ECOL
# Get data for: ECOM
# Get data for: ECPG
# Get data for: ED
# Get data for: EDIT
# Get data for: EDUC
# Get data for: EE
# Get data for: EEFT
# Get data for: EEX
# Get data for: EFC
# Get data for: EFOI
# Get data for: EFSC
# Get data for: EFX
# Get data for: EGAN
# Get data for: EGBN
# Get data for: EGHT
# Get data for: EGLE
# Get data for: EGOV
# Get data for: EGP
# Get data for: EGRX
# Get data for: EGY
# Get data for: EHC
# Get data for: EHTH
# Get data for: EIDX
# Get data for: EIG
# Get data for: EIGI
# Get data for: EIGR
# Get data for: EIX
# Get data for: EKSO
# Get data for: EL
# Get data for: ELAN
# Get data for: ELF
# Get data for: ELMD
# Get data for: ELOX
# Get data for: ELS
# Get data for: ELSE
# Get data for: ELVT
# Get data for: ELY
# Couldn't get data for: ELY
# Get data for: EMAN
# Get data for: EMCF
# Get data for: EME
# Get data for: EMKR
# Get data for: EML
# Get data for: EMMS
# Get data for: EMN
# Get data for: EMR
# Get data for: ENDP
# Get data for: ENG
# Get data for: ENOB
# Get data for: ENPH
# Get data for: ENR
# Get data for: ENS
# Get data for: ENSG
# Get data for: ENSV
# Get data for: ENTA
# Get data for: ENTG
# Get data for: ENV
# Get data for: ENVA
# Get data for: ENZ
# Get data for: EOG
# Get data for: EOLS
# Get data for: EPAM
# Get data for: EPAY
# Get data for: EPC
# Get data for: EPM
# Get data for: EPR
# Get data for: EPRT
# Get data for: EPZM
# Get data for: EQBK
# Get data for: EQC
# Get data for: EQH
# Get data for: EQIX
# Get data for: EQR
# Get data for: EQT
# Get data for: ERIE
# Get data for: ERII
# Get data for: ES
# Get data for: ESBK
# Get data for: ESCA
# Get data for: ESE
# Get data for: ESGR
# Get data for: ESI
# Get data for: ESNT
# Get data for: ESP
# Get data for: ESPR
# Get data for: ESQ
# Get data for: ESRT
# Get data for: ESS
# Get data for: ESSA
# Get data for: ESTC
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI',
#  'CBB',
#  'CBTX',
#  'CDEV',
#  'CDR',
#  'CECE',
#  'CLBS',
#  'CLR',
#  'CLSN',
#  'CLVS',
#  'CMD',
#  'CMO',
#  'CNR',
#  'COG',
#  'CRDB',
#  'CTT',
#  'CXO',
#  'CYTR',
#  'DRE',
#  'ELY']

# %%
for x in range(1000, 1500):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: ESTE
# Get data for: ESXB
# Get data for: ETN
# Get data for: ETR
# Get data for: ETRN
# Get data for: ETSY
# Get data for: EV
# Get data for: EVBG
# Get data for: EVBN
# Get data for: EVC
# Get data for: EVER
# Get data for: EVFM
# Get data for: EVH
# Get data for: EVI
# Get data for: EVOK
# Get data for: EVOL
# Get data for: EVOP
# Get data for: EVR
# Get data for: EVRG
# Get data for: EVRI
# Get data for: EVTC
# Get data for: EW
# Get data for: EWBC
# Get data for: EXAS
# Get data for: EXC
# Get data for: EXEL
# Get data for: EXLS
# Get data for: EXP
# Get data for: EXPD
# Get data for: EXPE
# Get data for: EXPI
# Get data for: EXPO
# Get data for: EXPR
# Get data for: EXR
# Get data for: EXTN
# Get data for: EXTR
# Get data for: EYE
# Get data for: EYEG
# Couldn't get data for: EYEG
# Get data for: EYES
# Couldn't get data for: EYES
# Get data for: EYPT
# Get data for: EZPW
# Get data for: F
# Get data for: FAF
# Get data for: FANG
# Get data for: FARM
# Get data for: FARO
# Get data for: FAST
# Get data for: FATE
# Get data for: FB
# Couldn't get data for: FB
# Get data for: FBC
# Get data for: FBHS
# Couldn't get data for: FBHS
# Get data for: FBIO
# Get data for: FBIZ
# Get data for: FBK
# Get data for: FBM
# Get data for: FBMS
# Get data for: FBNC
# Get data for: FBP
# Get data for: FBSS
# Get data for: FC
# Get data for: FCAP
# Get data for: FCBC
# Get data for: FCBP
# Get data for: FCCO
# Get data for: FCCY
# Get data for: FCEL
# Get data for: FCF
# Get data for: FCFS
# Get data for: FCN
# Get data for: FCNCA
# Get data for: FCPT
# Get data for: FCX
# Get data for: FDBC
# Get data for: FDP
# Get data for: FDS
# Get data for: FDX
# Get data for: FE
# Get data for: FEIM
# Get data for: FELE
# Get data for: FET
# Get data for: FF
# Get data for: FFBC
# Get data for: FFG
# Couldn't get data for: FFG
# Get data for: FFIC
# Get data for: FFIN
# Get data for: FFIV
# Get data for: FFNW
# Get data for: FFWM
# Get data for: FG
# Get data for: FGBI
# Get data for: FGEN
# Get data for: FHB
# Get data for: FHN
# Get data for: FIBK
# Get data for: FICO
# Get data for: FIS
# Get data for: FISI
# Get data for: FISV
# Get data for: FIT
# Get data for: FITB
# Get data for: FIVE
# Get data for: FIVN
# Get data for: FIX
# Get data for: FIXX
# Get data for: FIZZ
# Get data for: FL
# Get data for: FLIC
# Get data for: FLIR
# Get data for: FLL
# Get data for: FLNT
# Get data for: FLO
# Get data for: FLOW
# Get data for: FLR
# Get data for: FLS
# Get data for: FLT
# Get data for: FLWS
# Get data for: FLXN
# Get data for: FLXS
# Get data for: FMAO
# Get data for: FMBH
# Get data for: FMBI
# Get data for: FMC
# Get data for: FMNB
# Get data for: FN
# Get data for: FNB
# Get data for: FNCB
# Get data for: FND
# Get data for: FNF
# Get data for: FNHC
# Couldn't get data for: FNHC
# Get data for: FNKO
# Get data for: FNLC
# Get data for: FNWB
# Get data for: FOCS
# Get data for: FOE
# Get data for: FOLD
# Get data for: FONR
# Get data for: FOR
# Get data for: FORD
# Get data for: FORM
# Get data for: FORR
# Get data for: FOSL
# Get data for: FOX
# Get data for: FOXA
# Get data for: FOXF
# Get data for: FPI
# Get data for: FPRX
# Get data for: FR
# Get data for: FRAF
# Get data for: FRAN
# Couldn't get data for: FRAN
# Get data for: FRBA
# Get data for: FRBK
# Get data for: FRC
# Get data for: FRD
# Get data for: FRGI
# Get data for: FRME
# Get data for: FRPH
# Get data for: FRPT
# Get data for: FRT
# Get data for: FRTA
# Get data for: FSBW
# Get data for: FSCT
# Get data for: FSFG
# Get data for: FSLR
# Get data for: FSLY
# Get data for: FSP
# Get data for: FSS
# Get data for: FSTR
# Get data for: FTDR
# Get data for: FTEK
# Get data for: FTI
# Get data for: FTK
# Get data for: FTNT
# Get data for: FTSI
# Get data for: FTV
# Get data for: FUL
# Get data for: FULT
# Get data for: FUNC
# Get data for: FUSB
# Get data for: FVE
# Get data for: FWONA
# Get data for: FWONK
# Get data for: FWRD
# Get data for: G
# Get data for: GABC
# Get data for: GAIA
# Get data for: GALT
# Get data for: GATX
# Get data for: GBCI
# Get data for: GBL
# Couldn't get data for: GBL
# Get data for: GBLI
# Get data for: GBT
# Get data for: GBX
# Get data for: GCBC
# Get data for: GCI
# Get data for: GCO
# Get data for: GCP
# Get data for: GD
# Get data for: GDDY
# Get data for: GDEN
# Get data for: GDOT
# Get data for: GDP
# Get data for: GE
# Get data for: GEC
# Get data for: GEF
# Get data for: GEFB
# Couldn't get data for: GEFB
# Get data for: GEN
# Get data for: GENC
# Get data for: GEO
# Get data for: GEOS
# Get data for: GERN
# Get data for: GES
# Get data for: GEVO
# Get data for: GFED
# Get data for: GFF
# Get data for: GFN
# Couldn't get data for: GFN
# Get data for: GGG
# Get data for: GH
# Get data for: GHC
# Get data for: GHL
# Get data for: GHM
# Get data for: GIFI
# Get data for: GIII
# Get data for: GILD
# Get data for: GIS
# Get data for: GKOS
# Get data for: GL
# Get data for: GLBZ
# Get data for: GLDD
# Get data for: GLIBA
# Get data for: GLPI
# Get data for: GLRE
# Get data for: GLT
# Get data for: GLUU
# Get data for: GLW
# Get data for: GLYC
# Get data for: GM
# Get data for: GME
# Get data for: GMED
# Get data for: GMRE
# Get data for: GMS
# Get data for: GNCA
# Get data for: GNE
# Get data for: GNK
# Get data for: GNL
# Get data for: GNMK
# Get data for: GNRC
# Get data for: GNTX
# Get data for: GNTY
# Get data for: GNW
# Get data for: GOGO
# Get data for: GOLF
# Get data for: GOOD
# Get data for: GOOG
# Get data for: GOOGL
# Get data for: GORO
# Get data for: GOSS
# Get data for: GPC
# Get data for: GPI
# Get data for: GPK
# Get data for: GPMT
# Get data for: GPN
# Get data for: GPOR
# Get data for: GPRE
# Get data for: GPRO
# Get data for: GPS
# Get data for: GPX
# Get data for: GRA
# Get data for: GRBK
# Couldn't get data for: GRBK
# Get data for: GRC
# Get data for: GRMN
# Get data for: GROW
# Get data for: GRPN
# Get data for: GRTS
# Get data for: GRUB
# Get data for: GS
# Get data for: GSAT
# Get data for: GSBC
# Get data for: GSHD
# Get data for: GSIT
# Get data for: GSKY
# Get data for: GT
# Get data for: GTES
# Get data for: GTHX
# Get data for: GTIM
# Get data for: GTLS
# Get data for: GTN
# Get data for: GTS
# Get data for: GTT
# Couldn't get data for: GTT
# Get data for: GTX
# Get data for: GTY
# Get data for: GTYH
# Get data for: GV
# Get data for: GVA
# Get data for: GVP
# Get data for: GWB
# Get data for: GWGH
# Couldn't get data for: GWGH
# Get data for: GWRE
# Get data for: GWRS
# Get data for: GWW
# Get data for: H
# Get data for: HA
# Get data for: HAE
# Get data for: HAFC
# Get data for: HAIN
# Get data for: HAL
# Get data for: HALL
# Get data for: HALO
# Get data for: HAS
# Get data for: HASI
# Get data for: HAYN
# Get data for: HBAN
# Get data for: HBB
# Get data for: HBCP
# Get data for: HBI
# Get data for: HBIO
# Get data for: HBMD
# Get data for: HBNC
# Get data for: HBP
# Get data for: HCA
# Get data for: HCC
# Get data for: HCCI
# Get data for: HCHC
# Get data for: HCI
# Get data for: HCKT
# Get data for: HCP
# Get data for: HCSG
# Get data for: HD
# Get data for: HDS
# Get data for: HDSN
# Get data for: HE
# Get data for: HEAR
# Get data for: HEES
# Get data for: HEI
# Get data for: HEIA
# Couldn't get data for: HEIA
# Get data for: HELE
# Get data for: HEPA
# Get data for: HES
# Get data for: HFBL
# Get data for: HFWA
# Get data for: HGV
# Get data for: HHC
# Get data for: HHS
# Get data for: HI
# Get data for: HIBB
# Get data for: HIFS
# Get data for: HIG
# Get data for: HII
# Get data for: HIL
# Couldn't get data for: HIL
# Get data for: HIW
# Get data for: HL
# Get data for: HLF
# Get data for: HLI
# Get data for: HLIO
# Get data for: HLIT
# Get data for: HLNE
# Get data for: HLT
# Get data for: HLX
# Get data for: HMHC
# Get data for: HMN
# Get data for: HMNF
# Get data for: HMST
# Get data for: HMSY
# Get data for: HMTV
# Get data for: HNGR
# Get data for: HNI
# Get data for: HNRG
# Get data for: HOFT
# Get data for: HOG
# Get data for: HOLX
# Get data for: HOMB
# Get data for: HOME
# Get data for: HON
# Get data for: HONE
# Get data for: HOPE
# Get data for: HOV
# Get data for: HP
# Get data for: HPE
# Get data for: HPP
# Get data for: HPQ
# Get data for: HPR
# Couldn't get data for: HPR
# Get data for: HQY
# Get data for: HR
# Get data for: HRB
# Get data for: HRC
# Get data for: HRI
# Get data for: HRL
# Get data for: HROW
# Get data for: HRTG
# Get data for: HRTX
# Get data for: HSC
# Get data for: HSDT
# Get data for: HSIC
# Get data for: HSII
# Get data for: HSKA
# Get data for: HSON
# Get data for: HST
# Get data for: HSTM
# Get data for: HSY
# Get data for: HT
# Get data for: HTA
# Couldn't get data for: HTA
# Get data for: HTBI
# Get data for: HTBK
# Get data for: HTBX
# Couldn't get data for: HTBX
# Get data for: HTGM
# Get data for: HTH
# Get data for: HTLD
# Get data for: HTLF
# Get data for: HTZ
# Get data for: HUBB
# Get data for: HUBG
# Get data for: HUBS
# Get data for: HUM
# Get data for: HUN
# Get data for: HURC
# Get data for: HURN
# Get data for: HUSA
# Get data for: HVT
# Get data for: HWBK
# Get data for: HWC
# Get data for: HWCC
# Get data for: HWKN
# Get data for: HXL
# Get data for: HY
# Get data for: HZN
# Get data for: HZNP
# Get data for: HZO
# Get data for: IAA
# Get data for: IAC
# Get data for: IART
# Get data for: IBCP
# Get data for: IBIO
# Get data for: IBKR
# Get data for: IBM
# Get data for: IBOC
# Get data for: IBP
# Get data for: IBTX
# Get data for: ICAD
# Get data for: ICBK
# Get data for: ICCC
# Get data for: ICD
# Get data for: ICE
# Get data for: ICFI
# Get data for: ICHR
# Get data for: ICON
# Get data for: ICPT
# Get data for: ICUI
# Get data for: IDA
# Get data for: IDCC
# Get data for: IDN
# Get data for: IDRA
# Get data for: IDT
# Get data for: IDXG
# Get data for: IDXX
# Get data for: IEC
# Couldn't get data for: IEC
# Get data for: IESC
# Get data for: IEX
# Get data for: IFF
# Get data for: IHC
# Get data for: III
# Get data for: IIIN
# Get data for: IIIV
# Get data for: IIN
# Get data for: IIPR
# Get data for: IIVI
# Couldn't get data for: IIVI
# Get data for: ILMN
# Get data for: ILPT
# Get data for: IMBI
# Get data for: IMGN
# Get data for: IMH
# Get data for: IMKTA
# Get data for: IMMR
# Get data for: IMUX
# Get data for: IMXI
# Get data for: INBK
# Get data for: INCY
# Get data for: INDB
# Get data for: INFI
# Get data for: INFN
# Get data for: INFO
# Get data for: INFU
# Get data for: INGN
# Get data for: INGR
# Get data for: INN
# Get data for: INO
# Get data for: INOD
# Get data for: INOV
# Get data for: INPX
# Get data for: INS
# Couldn't get data for: INS
# Get data for: INSE
# Get data for: INSG
# Get data for: INSM
# Get data for: INSP
# Get data for: INST
# Get data for: INSW
# Get data for: INT
# Get data for: INTC
# Get data for: INTG
# Get data for: INTL
# Get data for: INTT
# Get data for: INTU
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI',
#  'CBB',
#  'CBTX',
#  'CDEV',
#  'CDR',
#  'CECE',
#  'CLBS',
#  'CLR',
#  'CLSN',
#  'CLVS',
#  'CMD',
#  'CMO',
#  'CNR',
#  'COG',
#  'CRDB',
#  'CTT',
#  'CXO',
#  'CYTR',
#  'DRE',
#  'ELY',
#  'EYEG',
#  'EYES',
#  'FB',
#  'FBHS',
#  'FFG',
#  'FNHC',
#  'FRAN',
#  'GBL',
#  'GEFB',
#  'GFN',
#  'GRBK',
#  'GTT',
#  'GWGH',
#  'HEIA',
#  'HIL',
#  'HPR',
#  'HTA',
#  'HTBX',
#  'IEC',
#  'IIVI',
#  'INS']

# %%
for x in range(1500, 2000):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: INUV
# Get data for: INVA
# Get data for: INVE
# Get data for: INVH
# Get data for: IO
# Couldn't get data for: IO
# Get data for: IONS
# Get data for: IOR
# Get data for: IOSP
# Get data for: IOVA
# Get data for: IP
# Get data for: IPAR
# Get data for: IPG
# Get data for: IPGP
# Get data for: IPHI
# Get data for: IPI
# Get data for: IPWR
# Get data for: IQV
# Get data for: IR
# Get data for: IRBT
# Get data for: IRDM
# Get data for: IRET
# Get data for: IRIX
# Get data for: IRM
# Get data for: IRMD
# Get data for: IROQ
# Get data for: IRT
# Get data for: IRTC
# Get data for: IRWD
# Get data for: ISBC
# Get data for: ISDR
# Get data for: ISEE
# Get data for: ISIG
# Get data for: ISNS
# Get data for: ISR
# Get data for: ISRG
# Get data for: ISSC
# Get data for: ISTR
# Get data for: IT
# Get data for: ITCI
# Get data for: ITGR
# Get data for: ITI
# Get data for: ITIC
# Get data for: ITRI
# Get data for: ITT
# Get data for: ITW
# Get data for: IVAC
# Get data for: IVC
# Get data for: IVR
# Get data for: IVZ
# Get data for: IZEA
# Get data for: JACK
# Get data for: JAGX
# Get data for: JAKK
# Get data for: JAX
# Get data for: JAZZ
# Get data for: JBGS
# Get data for: JBHT
# Get data for: JBL
# Get data for: JBLU
# Get data for: JBSS
# Get data for: JBT
# Get data for: JCI
# Get data for: JCS
# Couldn't get data for: JCS
# Get data for: JCTCF
# Get data for: JEF
# Get data for: JELD
# Get data for: JHG
# Get data for: JILL
# Get data for: JJSF
# Get data for: JKHY
# Get data for: JLL
# Get data for: JNCE
# Get data for: JNJ
# Get data for: JNPR
# Get data for: JOB
# Get data for: JOE
# Get data for: JOUT
# Get data for: JPM
# Get data for: JRVR
# Get data for: JVA
# Get data for: JWN
# Get data for: JYNT
# Get data for: K
# Get data for: KAI
# Get data for: KALA
# Get data for: KALU
# Get data for: KALV
# Get data for: KAMN
# Get data for: KAR
# Get data for: KBAL
# Get data for: KBH
# Get data for: KBR
# Get data for: KDMN
# Get data for: KDP
# Get data for: KE
# Get data for: KELYA
# Get data for: KEQU
# Get data for: KEX
# Get data for: KEY
# Get data for: KEYS
# Get data for: KFFB
# Get data for: KFRC
# Get data for: KFY
# Get data for: KHC
# Get data for: KIDS
# Get data for: KIM
# Get data for: KIN
# Couldn't get data for: KIN
# Get data for: KINS
# Get data for: KIRK
# Get data for: KKR
# Get data for: KLAC
# Get data for: KLIC
# Get data for: KLXE
# Get data for: KMB
# Get data for: KMI
# Get data for: KMPH
# Get data for: KMPR
# Get data for: KMT
# Get data for: KMX
# Get data for: KN
# Get data for: KNL
# Get data for: KNSA
# Get data for: KNSL
# Get data for: KNX
# Get data for: KO
# Get data for: KOD
# Get data for: KODK
# Get data for: KOOL
# Get data for: KOP
# Get data for: KOPN
# Get data for: KOS
# Get data for: KPTI
# Get data for: KR
# Get data for: KRA
# Get data for: KRC
# Get data for: KREF
# Get data for: KRG
# Get data for: KRNY
# Get data for: KRO
# Get data for: KRYS
# Get data for: KSS
# Get data for: KSU
# Get data for: KTB
# Get data for: KTCC
# Get data for: KTOS
# Get data for: KURA
# Get data for: KVHI
# Get data for: KW
# Get data for: KWR
# Get data for: KZR
# Get data for: L
# Get data for: LAD
# Get data for: LADR
# Get data for: LAKE
# Get data for: LAMR
# Get data for: LANC
# Get data for: LAND
# Get data for: LARK
# Get data for: LASR
# Get data for: LAUR
# Get data for: LAZ
# Get data for: LB
# Couldn't get data for: LB
# Get data for: LBAI
# Get data for: LBC
# Get data for: LBRDA
# Get data for: LBRDK
# Get data for: LBRT
# Get data for: LBTYA
# Get data for: LBTYK
# Get data for: LC
# Get data for: LCI
# Get data for: LCII
# Get data for: LCNB
# Get data for: LCTX
# Get data for: LCUT
# Get data for: LDL
# Get data for: LDOS
# Get data for: LE
# Get data for: LEA
# Get data for: LEAF
# Get data for: LECO
# Get data for: LEE
# Get data for: LEG
# Get data for: LEGH
# Get data for: LEN
# Get data for: LENB
# Couldn't get data for: LENB
# Get data for: LEU
# Get data for: LEVI
# Get data for: LFUS
# Get data for: LFVN
# Get data for: LGFA
# Get data for: LGFB
# Couldn't get data for: LGFB
# Get data for: LGIH
# Get data for: LGL
# Get data for: LGND
# Get data for: LH
# Get data for: LHCG
# Get data for: LHX
# Get data for: LIFE
# Get data for: LII
# Get data for: LILA
# Get data for: LILAK
# Get data for: LIN
# Get data for: LINC
# Get data for: LIND
# Get data for: LIQT
# Get data for: LITE
# Get data for: LIVE
# Get data for: LIVN
# Get data for: LIVX
# Get data for: LJPC
# Couldn't get data for: LJPC
# Get data for: LKFN
# Get data for: LKQ
# Get data for: LL
# Get data for: LLNW
# Couldn't get data for: LLNW
# Get data for: LLY
# Get data for: LMAT
# Get data for: LMFA
# Get data for: LMNR
# Get data for: LMNX
# Get data for: LMST
# Get data for: LMT
# Get data for: LNC
# Get data for: LNDC
# Couldn't get data for: LNDC
# Get data for: LNG
# Get data for: LNN
# Get data for: LNT
# Get data for: LNTH
# Get data for: LOAN
# Get data for: LOB
# Get data for: LOCO
# Get data for: LODE
# Get data for: LONE
# Get data for: LOOP
# Get data for: LOPE
# Get data for: LORL
# Get data for: LOVE
# Get data for: LOW
# Get data for: LPCN
# Get data for: LPG
# Get data for: LPI
# Get data for: LPLA
# Get data for: LPSN
# Get data for: LPTH
# Get data for: LPX
# Get data for: LQDA
# Get data for: LQDT
# Get data for: LRCX
# Get data for: LRN
# Get data for: LSBK
# Get data for: LSCC
# Get data for: LSI
# Get data for: LSTR
# Get data for: LSXMA
# Get data for: LSXMK
# Get data for: LTBR
# Get data for: LTC
# Get data for: LTHM
# Get data for: LTRPA
# Get data for: LTRX
# Get data for: LUB
# Get data for: LULU
# Get data for: LUNA
# Get data for: LUV
# Get data for: LVS
# Get data for: LW
# Get data for: LWAY
# Get data for: LXP
# Get data for: LXRX
# Get data for: LXU
# Get data for: LYB
# Get data for: LYFT
# Get data for: LYTS
# Get data for: LYV
# Get data for: LZB
# Get data for: M
# Get data for: MA
# Get data for: MAA
# Get data for: MAC
# Get data for: MACK
# Get data for: MAN
# Get data for: MANH
# Get data for: MANT
# Get data for: MAR
# Get data for: MARA
# Get data for: MARK
# Get data for: MAS
# Get data for: MASI
# Get data for: MAT
# Get data for: MATW
# Get data for: MATX
# Get data for: MAYS
# Get data for: MBCN
# Get data for: MBI
# Get data for: MBII
# Get data for: MBIN
# Get data for: MBIO
# Get data for: MBOT
# Get data for: MBUU
# Get data for: MBWM
# Get data for: MC
# Get data for: MCB
# Get data for: MCBC
# Get data for: MCD
# Get data for: MCF
# Get data for: MCFT
# Get data for: MCHP
# Get data for: MCHX
# Get data for: MCK
# Get data for: MCO
# Get data for: MCRB
# Get data for: MCRI
# Get data for: MCS
# Get data for: MCY
# Get data for: MD
# Get data for: MDB
# Get data for: MDC
# Get data for: MDGL
# Get data for: MDLY
# Couldn't get data for: MDLY
# Get data for: MDLZ
# Get data for: MDP
# Couldn't get data for: MDP
# Get data for: MDRX
# Get data for: MDT
# Get data for: MDU
# Get data for: MED
# Get data for: MEDP
# Get data for: MEI
# Get data for: MEIP
# Get data for: MERC
# Get data for: MESA
# Get data for: MET
# Get data for: MFA
# Get data for: MFNC
# Get data for: MG
# Get data for: MGEE
# Get data for: MGI
# Get data for: MGLN
# Get data for: MGM
# Get data for: MGNX
# Get data for: MGPI
# Get data for: MGRC
# Get data for: MGTA
# Get data for: MGY
# Get data for: MGYR
# Get data for: MHH
# Get data for: MHK
# Get data for: MHLD
# Get data for: MHO
# Get data for: MIC
# Get data for: MICR
# Get data for: MICT
# Get data for: MIDD
# Get data for: MIK
# Get data for: MIND
# Get data for: MITK
# Get data for: MITT
# Get data for: MKC
# Get data for: MKL
# Get data for: MKSI
# Get data for: MKTX
# Get data for: MLAB
# Get data for: MLHR
# Couldn't get data for: MLHR
# Get data for: MLI
# Get data for: MLM
# Get data for: MLP
# Get data for: MLR
# Get data for: MLSS
# Get data for: MLVF
# Get data for: MMAC
# Get data for: MMC
# Get data for: MMI
# Get data for: MMM
# Get data for: MMS
# Get data for: MMSI
# Get data for: MN
# Get data for: MNK
# Get data for: MNKD
# Get data for: MNOV
# Get data for: MNR
# Get data for: MNRL
# Get data for: MNRO
# Get data for: MNSB
# Get data for: MNST
# Get data for: MNTX
# Get data for: MO
# Get data for: MOBL
# Get data for: MOD
# Get data for: MODN
# Get data for: MOFG
# Get data for: MOGA
# Get data for: MOH
# Get data for: MORN
# Get data for: MOS
# Get data for: MOTS
# Get data for: MOV
# Get data for: MPAA
# Get data for: MPB
# Get data for: MPC
# Get data for: MPW
# Get data for: MPWR
# Get data for: MPX
# Get data for: MRAM
# Get data for: MRBK
# Get data for: MRC
# Get data for: MRCY
# Get data for: MRIN
# Get data for: MRK
# Get data for: MRKR
# Get data for: MRLN
# Get data for: MRNS
# Get data for: MRO
# Get data for: MRSN
# Get data for: MRTN
# Get data for: MRTX
# Get data for: MRVL
# Get data for: MS
# Get data for: MSA
# Get data for: MSBI
# Get data for: MSCI
# Get data for: MSEX
# Get data for: MSFT
# Get data for: MSGN
# Get data for: MSI
# Get data for: MSM
# Get data for: MSN
# Get data for: MSON
# Get data for: MSTR
# Get data for: MTB
# Get data for: MTCH
# Get data for: MTD
# Get data for: MTDR
# Get data for: MTEM
# Get data for: MTEX
# Get data for: MTG
# Get data for: MTH
# Get data for: MTN
# Get data for: MTNB
# Get data for: MTOR
# Get data for: MTRN
# Get data for: MTRX
# Get data for: MTSC
# Get data for: MTSI
# Get data for: MTW
# Get data for: MTX
# Get data for: MTZ
# Get data for: MU
# Get data for: MUR
# Get data for: MUSA
# Get data for: MUX
# Get data for: MVBF
# Get data for: MVIS
# Get data for: MWA
# Get data for: MXIM
# Get data for: MXL
# Get data for: MYE
# Get data for: MYGN
# Get data for: MYRG
# Get data for: NAII
# Get data for: NATH
# Get data for: NATI
# Get data for: NATR
# Get data for: NAV
# Couldn't get data for: NAV
# Get data for: NAVB
# Get data for: NAVI
# Get data for: NBEV
# Couldn't get data for: NBEV
# Get data for: NBHC
# Get data for: NBIX
# Get data for: NBN
# Get data for: NBR
# Get data for: NBSE
# Get data for: NBTB
# Get data for: NBY
# Get data for: NC
# Get data for: NCBS
# Get data for: NCLH
# Get data for: NCMI
# Get data for: NCR
# Get data for: NCSM
# Get data for: NDAQ
# Get data for: NDLS
# Get data for: NDSN
# Get data for: NE
# Get data for: NEE
# Get data for: NEM
# Get data for: NEO
# Get data for: NEOG
# Get data for: NEON
# Get data for: NEOS
# Get data for: NERV
# Get data for: NETE
# Couldn't get data for: NETE
# Get data for: NEU
# Get data for: NEWR
# Get data for: NFBK
# Get data for: NFG
# Get data for: NFLX
# Get data for: NGHC
# Get data for: NGS
# Get data for: NGVC
# Get data for: NGVT
# Get data for: NHC
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI',
#  'CBB',
#  'CBTX',
#  'CDEV',
#  'CDR',
#  'CECE',
#  'CLBS',
#  'CLR',
#  'CLSN',
#  'CLVS',
#  'CMD',
#  'CMO',
#  'CNR',
#  'COG',
#  'CRDB',
#  'CTT',
#  'CXO',
#  'CYTR',
#  'DRE',
#  'ELY',
#  'EYEG',
#  'EYES',
#  'FB',
#  'FBHS',
#  'FFG',
#  'FNHC',
#  'FRAN',
#  'GBL',
#  'GEFB',
#  'GFN',
#  'GRBK',
#  'GTT',
#  'GWGH',
#  'HEIA',
#  'HIL',
#  'HPR',
#  'HTA',
#  'HTBX',
#  'IEC',
#  'IIVI',
#  'INS',
#  'IO',
#  'JCS',
#  'KIN',
#  'LB',
#  'LENB',
#  'LGFB',
#  'LJPC',
#  'LLNW',
#  'LNDC',
#  'MDLY',
#  'MDP',
#  'MLHR',
#  'NAV',
#  'NBEV',
#  'NETE']

# %%
for x in range(2000, 2500):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: NHI
# Get data for: NHTC
# Get data for: NI
# Get data for: NICK
# Get data for: NINE
# Get data for: NJR
# Get data for: NKE
# Get data for: NKSH
# Get data for: NKTR
# Get data for: NL
# Get data for: NLS
# Get data for: NLSN
# Get data for: NLTX
# Get data for: NLY
# Get data for: NMIH
# Get data for: NMRK
# Get data for: NNBR
# Get data for: NNI
# Get data for: NNN
# Get data for: NNVC
# Get data for: NOC
# Get data for: NODK
# Get data for: NOG
# Get data for: NOV
# Get data for: NOVT
# Get data for: NOW
# Get data for: NP
# Get data for: NPK
# Get data for: NPO
# Get data for: NPTN
# Get data for: NR
# Get data for: NRC
# Get data for: NRG
# Get data for: NRIM
# Get data for: NRZ
# Couldn't get data for: NRZ
# Get data for: NSA
# Get data for: NSC
# Get data for: NSEC
# Get data for: NSIT
# Get data for: NSP
# Get data for: NSSC
# Get data for: NSTG
# Get data for: NTAP
# Get data for: NTCT
# Get data for: NTGR
# Get data for: NTIC
# Get data for: NTIP
# Get data for: NTLA
# Get data for: NTNX
# Get data for: NTRA
# Get data for: NTRS
# Get data for: NTUS
# Get data for: NTWK
# Get data for: NUAN
# Get data for: NUE
# Get data for: NURO
# Get data for: NUS
# Get data for: NUVA
# Get data for: NVAX
# Get data for: NVDA
# Get data for: NVEC
# Get data for: NVEE
# Get data for: NVFY
# Get data for: NVIV
# Get data for: NVR
# Get data for: NVRO
# Get data for: NVT
# Get data for: NVTA
# Get data for: NWBI
# Get data for: NWE
# Get data for: NWFL
# Get data for: NWHM
# Get data for: NWL
# Get data for: NWLI
# Get data for: NWN
# Get data for: NWPX
# Get data for: NWS
# Get data for: NWSA
# Get data for: NX
# Get data for: NXGN
# Get data for: NXRT
# Get data for: NXST
# Get data for: NXTD
# Couldn't get data for: NXTD
# Get data for: NYCB
# Get data for: NYMT
# Get data for: NYT
# Get data for: O
# Get data for: OAS
# Get data for: OBCI
# Get data for: OBNK
# Get data for: OC
# Get data for: OCC
# Get data for: OCFC
# Get data for: OCN
# Get data for: OCUL
# Get data for: OCX
# Get data for: ODC
# Get data for: ODFL
# Get data for: ODP
# Get data for: ODT
# Couldn't get data for: ODT
# Get data for: OESX
# Get data for: OFC
# Get data for: OFED
# Get data for: OFG
# Get data for: OFIX
# Get data for: OFLX
# Get data for: OGE
# Get data for: OGEN
# Get data for: OGS
# Get data for: OHI
# Get data for: OI
# Get data for: OII
# Get data for: OIS
# Get data for: OKE
# Get data for: OKTA
# Get data for: OLED
# Get data for: OLLI
# Get data for: OLN
# Get data for: OLP
# Get data for: OMC
# Get data for: OMCL
# Get data for: OMED
# Couldn't get data for: OMED
# Get data for: OMER
# Get data for: OMEX
# Get data for: OMF
# Get data for: OMI
# Get data for: ON
# Get data for: ONB
# Get data for: ONCS
# Get data for: ONCT
# Get data for: ONTX
# Get data for: ONVO
# Get data for: OOMA
# Get data for: OPGN
# Get data for: OPI
# Get data for: OPK
# Get data for: OPOF
# Get data for: OPRX
# Get data for: OPTN
# Get data for: OPTT
# Get data for: OPY
# Get data for: ORA
# Get data for: ORBC
# Get data for: ORC
# Get data for: ORCL
# Get data for: ORGO
# Get data for: ORI
# Get data for: ORLY
# Get data for: ORN
# Get data for: ORRF
# Get data for: OSBC
# Get data for: OSG
# Get data for: OSIS
# Get data for: OSK
# Get data for: OSPN
# Get data for: OSTK
# Get data for: OSUR
# Get data for: OSW
# Get data for: OTEL
# Get data for: OTIC
# Get data for: OTTR
# Get data for: OUT
# Get data for: OVBC
# Get data for: OVLY
# Get data for: OXM
# Get data for: OXY
# Get data for: OZK
# Get data for: PACB
# Get data for: PACW
# Get data for: PAG
# Get data for: PAHC
# Get data for: PANL
# Get data for: PANW
# Get data for: PAR
# Get data for: PARR
# Get data for: PATI
# Get data for: PATK
# Get data for: PAYC
# Get data for: PAYS
# Get data for: PAYX
# Get data for: PB
# Get data for: PBCT
# Get data for: PBF
# Get data for: PBH
# Get data for: PBHC
# Get data for: PBI
# Get data for: PBIP
# Get data for: PBPB
# Get data for: PBYI
# Get data for: PCAR
# Get data for: PCH
# Get data for: PCRX
# Get data for: PCSB
# Get data for: PCTI
# Get data for: PCTY
# Get data for: PCYG
# Get data for: PCYO
# Get data for: PD
# Get data for: PDCE
# Get data for: PDCO
# Get data for: PDEX
# Get data for: PDFS
# Get data for: PDLB
# Get data for: PDLI
# Get data for: PDM
# Get data for: PDSB
# Get data for: PE
# Get data for: PEB
# Get data for: PEBK
# Get data for: PEBO
# Get data for: PED
# Get data for: PEG
# Get data for: PEGA
# Get data for: PEI
# Couldn't get data for: PEI
# Get data for: PEN
# Get data for: PENN
# Get data for: PEP
# Get data for: PESI
# Get data for: PETQ
# Get data for: PETS
# Get data for: PFBC
# Get data for: PFBI
# Get data for: PFE
# Get data for: PFG
# Get data for: PFGC
# Get data for: PFIE
# Get data for: PFIN
# Get data for: PFIS
# Get data for: PFMT
# Get data for: PFPT
# Get data for: PFS
# Get data for: PFSW
# Get data for: PG
# Get data for: PGC
# Get data for: PGR
# Get data for: PGRE
# Get data for: PGTI
# Get data for: PH
# Get data for: PHAS
# Get data for: PHIO
# Get data for: PHM
# Get data for: PHX
# Get data for: PI
# Get data for: PII
# Get data for: PINC
# Get data for: PINS
# Get data for: PJT
# Get data for: PK
# Get data for: PKBK
# Get data for: PKE
# Get data for: PKG
# Get data for: PKI
# Get data for: PKOH
# Get data for: PLAB
# Get data for: PLAN
# Get data for: PLAY
# Get data for: PLBC
# Get data for: PLCE
# Get data for: PLD
# Get data for: PLNT
# Get data for: PLOW
# Get data for: PLPC
# Get data for: PLSE
# Get data for: PLUG
# Get data for: PLUS
# Get data for: PLXP
# Get data for: PLXS
# Get data for: PLYA
# Get data for: PLYM
# Get data for: PM
# Get data for: PMBC
# Get data for: PMD
# Get data for: PMT
# Get data for: PMTS
# Get data for: PNBK
# Get data for: PNC
# Get data for: PNFP
# Get data for: PNM
# Get data for: PNR
# Get data for: PNRG
# Get data for: PNW
# Get data for: POAI
# Get data for: PODD
# Get data for: POL
# Get data for: POOL
# Get data for: POR
# Get data for: POST
# Get data for: POWI
# Get data for: POWL
# Get data for: PPBI
# Get data for: PPC
# Get data for: PPG
# Get data for: PPIH
# Get data for: PPL
# Get data for: PPSI
# Get data for: PRA
# Get data for: PRAA
# Get data for: PRAH
# Get data for: PRCP
# Get data for: PRFT
# Get data for: PRGO
# Get data for: PRGS
# Get data for: PRGX
# Get data for: PRI
# Get data for: PRIM
# Get data for: PRK
# Get data for: PRLB
# Get data for: PRMW
# Get data for: PRO
# Get data for: PROV
# Get data for: PRPH
# Get data for: PRSC
# Get data for: PRSP
# Get data for: PRTA
# Get data for: PRTK
# Get data for: PRTS
# Get data for: PRTY
# Get data for: PRU
# Get data for: PRVB
# Get data for: PS
# Get data for: PSA
# Get data for: PSB
# Get data for: PSMT
# Get data for: PSN
# Get data for: PSTG
# Get data for: PSTV
# Get data for: PSX
# Get data for: PTC
# Get data for: PTCT
# Get data for: PTE
# Get data for: PTEN
# Get data for: PTGX
# Get data for: PTI
# Get data for: PTN
# Get data for: PTSI
# Get data for: PTVCA
# Get data for: PTVCB
# Get data for: PULM
# Get data for: PUMP
# Get data for: PVAC
# Get data for: PVBC
# Get data for: PVH
# Get data for: PW
# Get data for: PWOD
# Get data for: PWR
# Get data for: PXD
# Get data for: PXLW
# Get data for: PYPL
# Get data for: PZG
# Get data for: PZN
# Get data for: PZZA
# Get data for: QADA
# Get data for: QADB
# Get data for: QCOM
# Get data for: QCRH
# Get data for: QDEL
# Get data for: QEP
# Get data for: QLYS
# Get data for: QNST
# Get data for: QRHC
# Get data for: QRTEA
# Get data for: QRVO
# Get data for: QTRX
# Get data for: QTS
# Get data for: QTWO
# Get data for: QUAD
# Get data for: QUIK
# Get data for: QUMU
# Get data for: QUOT
# Get data for: R
# Get data for: RAD
# Get data for: RAIL
# Get data for: RAMP
# Get data for: RARE
# Get data for: RAVE
# Get data for: RAVN
# Get data for: RBB
# Get data for: RBBN
# Get data for: RBC
# Get data for: RBCAA
# Get data for: RBCN
# Get data for: RBNC
# Get data for: RC
# Get data for: RCII
# Get data for: RCKT
# Get data for: RCKY
# Get data for: RCL
# Get data for: RCM
# Get data for: RCMT
# Get data for: RCUS
# Get data for: RDFN
# Get data for: RDI
# Get data for: RDN
# Get data for: RDNT
# Get data for: RDUS
# Get data for: RDVT
# Get data for: RE
# Get data for: REED
# Get data for: REFR
# Get data for: REG
# Get data for: REGI
# Get data for: REGN
# Get data for: REI
# Get data for: RELL
# Get data for: RELV
# Get data for: REPL
# Get data for: RES
# Get data for: RESI
# Get data for: RESN
# Get data for: RETA
# Get data for: REV
# Couldn't get data for: REV
# Get data for: REVG
# Get data for: REX
# Get data for: REXR
# Get data for: REZI
# Get data for: RF
# Get data for: RFIL
# Get data for: RFL
# Get data for: RFP
# Get data for: RGA
# Get data for: RGCO
# Get data for: RGEN
# Get data for: RGLD
# Get data for: RGLS
# Get data for: RGNX
# Get data for: RGR
# Get data for: RGS
# Get data for: RH
# Get data for: RHE
# Get data for: RHI
# Get data for: RHP
# Get data for: RIBT
# Get data for: RICK
# Get data for: RIG
# Get data for: RIGL
# Get data for: RILY
# Get data for: RIOT
# Get data for: RJF
# Get data for: RKDA
# Get data for: RL
# Get data for: RLGT
# Get data for: RLH
# Get data for: RLI
# Get data for: RLJ
# Get data for: RM
# Get data for: RMAX
# Get data for: RMBS
# Get data for: RMCF
# Get data for: RMD
# Get data for: RMR
# Get data for: RMTI
# Get data for: RNDB
# Get data for: RNET
# Get data for: RNG
# Get data for: RNR
# Get data for: RNST
# Get data for: RNWK
# Get data for: ROAD
# Get data for: ROCK
# Get data for: ROG
# Get data for: ROIC
# Get data for: ROK
# Get data for: ROKU
# Get data for: ROL
# Get data for: ROLL
# Get data for: ROP
# Get data for: ROST
# Get data for: RP
# Get data for: RPAI
# Get data for: RPD
# Get data for: RPM
# Get data for: RPT
# Get data for: RRC
# Get data for: RRD
# Get data for: RRGB
# Get data for: RRR
# Get data for: RRTS
# Get data for: RS
# Get data for: RSG
# Get data for: RUBY
# Get data for: RUN
# Get data for: RUSHA
# Get data for: RUSHB
# Get data for: RUTH
# Get data for: RVI
# Couldn't get data for: RVI
# Get data for: RVNC
# Get data for: RVP
# Get data for: RVSB
# Get data for: RWT
# Get data for: RYAM
# Get data for: RYI
# Get data for: RYN
# Get data for: RYTM
# Get data for: S
# Get data for: SABR
# Get data for: SACH
# Get data for: SAFE
# Get data for: SAFM
# Get data for: SAFT
# Get data for: SAGE
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI',
#  'CBB',
#  'CBTX',
#  'CDEV',
#  'CDR',
#  'CECE',
#  'CLBS',
#  'CLR',
#  'CLSN',
#  'CLVS',
#  'CMD',
#  'CMO',
#  'CNR',
#  'COG',
#  'CRDB',
#  'CTT',
#  'CXO',
#  'CYTR',
#  'DRE',
#  'ELY',
#  'EYEG',
#  'EYES',
#  'FB',
#  'FBHS',
#  'FFG',
#  'FNHC',
#  'FRAN',
#  'GBL',
#  'GEFB',
#  'GFN',
#  'GRBK',
#  'GTT',
#  'GWGH',
#  'HEIA',
#  'HIL',
#  'HPR',
#  'HTA',
#  'HTBX',
#  'IEC',
#  'IIVI',
#  'INS',
#  'IO',
#  'JCS',
#  'KIN',
#  'LB',
#  'LENB',
#  'LGFB',
#  'LJPC',
#  'LLNW',
#  'LNDC',
#  'MDLY',
#  'MDP',
#  'MLHR',
#  'NAV',
#  'NBEV',
#  'NETE',
#  'NRZ',
#  'NXTD',
#  'ODT',
#  'OMED',
#  'PEI',
#  'REV',
#  'RVI']

# %%
for x in range(2500, 3000):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: SAH
# Get data for: SAIA
# Get data for: SAIC
# Get data for: SAIL
# Get data for: SAL
# Get data for: SALM
# Get data for: SAM
# Get data for: SAMG
# Get data for: SANM
# Get data for: SANW
# Get data for: SASR
# Get data for: SATS
# Get data for: SAVA
# Get data for: SAVE
# Get data for: SBAC
# Get data for: SBCF
# Get data for: SBFG
# Get data for: SBGI
# Get data for: SBH
# Get data for: SBNY
# Get data for: SBOW
# Get data for: SBRA
# Get data for: SBSI
# Get data for: SBT
# Get data for: SBUX
# Get data for: SC
# Get data for: SCHL
# Get data for: SCHN
# Get data for: SCHW
# Get data for: SCI
# Get data for: SCL
# Get data for: SCON
# Couldn't get data for: SCON
# Get data for: SCOR
# Get data for: SCPL
# Get data for: SCS
# Get data for: SCSC
# Get data for: SCVL
# Get data for: SCWX
# Get data for: SCX
# Get data for: SCYX
# Get data for: SD
# Get data for: SDPI
# Get data for: SEAC
# Get data for: SEAS
# Get data for: SEB
# Get data for: SEDG
# Get data for: SEE
# Get data for: SEEL
# Get data for: SEIC
# Get data for: SELB
# Get data for: SELF
# Get data for: SEM
# Get data for: SENEA
# Get data for: SENEB
# Get data for: SENS
# Get data for: SES
# Get data for: SESN
# Get data for: SF
# Get data for: SFBC
# Get data for: SFBS
# Get data for: SFE
# Get data for: SFIX
# Get data for: SFM
# Get data for: SFNC
# Get data for: SFST
# Get data for: SGA
# Get data for: SGC
# Get data for: SGEN
# Get data for: SGH
# Get data for: SGMA
# Get data for: SGMO
# Get data for: SGRP
# Get data for: SGRY
# Get data for: SHAK
# Get data for: SHBI
# Get data for: SHEN
# Get data for: SHO
# Get data for: SHOO
# Get data for: SHSP
# Get data for: SHW
# Get data for: SIBN
# Get data for: SIEB
# Get data for: SIEN
# Get data for: SIF
# Get data for: SIG
# Get data for: SIGA
# Get data for: SIGI
# Get data for: SILK
# Get data for: SINT
# Get data for: SIRI
# Get data for: SITC
# Get data for: SITE
# Get data for: SIVB
# Get data for: SIX
# Get data for: SJI
# Get data for: SJM
# Get data for: SJW
# Get data for: SKT
# Get data for: SKX
# Get data for: SKY
# Get data for: SKYW
# Get data for: SLAB
# Get data for: SLB
# Get data for: SLCA
# Get data for: SLCT
# Get data for: SLDB
# Get data for: SLG
# Get data for: SLGN
# Get data for: SLM
# Get data for: SLNG
# Get data for: SLNO
# Get data for: SLP
# Get data for: SLRX
# Get data for: SLS
# Get data for: SM
# Get data for: SMAR
# Get data for: SMBC
# Get data for: SMBK
# Get data for: SMED
# Get data for: SMG
# Get data for: SMHI
# Get data for: SMIT
# Get data for: SMMF
# Get data for: SMP
# Get data for: SMPL
# Get data for: SMRT
# Get data for: SMSI
# Get data for: SMTC
# Get data for: SNA
# Get data for: SNAP
# Get data for: SNBR
# Get data for: SNCR
# Get data for: SND
# Get data for: SNDR
# Get data for: SNDX
# Get data for: SNFCA
# Get data for: SNOA
# Get data for: SNPS
# Get data for: SNR
# Get data for: SNV
# Get data for: SNX
# Get data for: SO
# Get data for: SOHO
# Get data for: SOI
# Get data for: SOLY
# Get data for: SON
# Get data for: SONO
# Get data for: SP
# Get data for: SPB
# Get data for: SPG
# Get data for: SPGI
# Get data for: SPLK
# Get data for: SPNE
# Get data for: SPOK
# Get data for: SPPI
# Get data for: SPR
# Get data for: SPRO
# Get data for: SPRT
# Get data for: SPSC
# Get data for: SPTN
# Get data for: SPWH
# Get data for: SPWR
# Get data for: SPXC
# Get data for: SQ
# Get data for: SQBG
# Couldn't get data for: SQBG
# Get data for: SR
# Get data for: SRC
# Get data for: SRCE
# Get data for: SRCL
# Get data for: SRDX
# Get data for: SRE
# Get data for: SREV
# Get data for: SRG
# Get data for: SRI
# Get data for: SRNE
# Get data for: SRPT
# Get data for: SRRK
# Get data for: SRT
# Get data for: SRTS
# Get data for: SSB
# Get data for: SSBI
# Get data for: SSD
# Get data for: SSKN
# Get data for: SSNC
# Get data for: SSP
# Get data for: SSTI
# Get data for: SSTK
# Get data for: ST
# Get data for: STAA
# Get data for: STAG
# Get data for: STAR
# Get data for: STAY
# Get data for: STBA
# Get data for: STC
# Get data for: STCN
# Get data for: STE
# Get data for: STFC
# Get data for: STIM
# Get data for: STKS
# Get data for: STL
# Get data for: STLD
# Get data for: STMP
# Get data for: STND
# Get data for: STOR
# Get data for: STRA
# Get data for: STRL
# Get data for: STRM
# Get data for: STRS
# Get data for: STRT
# Get data for: STT
# Get data for: STWD
# Get data for: STX
# Get data for: STXB
# Get data for: STZ
# Get data for: SUI
# Get data for: SUM
# Get data for: SUMR
# Get data for: SUNW
# Get data for: SUP
# Get data for: SUPN
# Get data for: SVBI
# Get data for: SVRA
# Get data for: SVT
# Get data for: SWAV
# Get data for: SWCH
# Get data for: SWK
# Get data for: SWKS
# Get data for: SWM
# Couldn't get data for: SWM
# Get data for: SWN
# Get data for: SWX
# Get data for: SXC
# Get data for: SXI
# Get data for: SXT
# Get data for: SYBT
# Get data for: SYBX
# Get data for: SYF
# Get data for: SYK
# Get data for: SYKE
# Get data for: SYN
# Couldn't get data for: SYN
# Get data for: SYNA
# Get data for: SYNC
# Get data for: SYNH
# Get data for: SYNL
# Couldn't get data for: SYNL
# Get data for: SYPR
# Get data for: SYRS
# Get data for: SYY
# Get data for: T
# Get data for: TACO
# Get data for: TACT
# Get data for: TAIT
# Get data for: TALO
# Get data for: TAP
# Get data for: TAST
# Get data for: TAT
# Get data for: TAYD
# Get data for: TBBK
# Get data for: TBI
# Get data for: TBIO
# Get data for: TBK
# Couldn't get data for: TBK
# Get data for: TBNK
# Get data for: TBPH
# Get data for: TCBI
# Get data for: TCBK
# Get data for: TCDA
# Get data for: TCF
# Couldn't get data for: TCF
# Get data for: TCFC
# Get data for: TCI
# Get data for: TCMD
# Get data for: TCO
# Couldn't get data for: TCO
# Get data for: TCON
# Get data for: TCS
# Get data for: TDC
# Get data for: TDG
# Get data for: TDOC
# Get data for: TDS
# Get data for: TDW
# Get data for: TDY
# Get data for: TECD
# Get data for: TECH
# Get data for: TEL
# Get data for: TELL
# Get data for: TEN
# Get data for: TENB
# Get data for: TENX
# Get data for: TER
# Get data for: TESS
# Get data for: TEUM
# Get data for: TEX
# Get data for: TFSL
# Get data for: TFX
# Get data for: TG
# Get data for: TGEN
# Get data for: TGI
# Get data for: TGLS
# Get data for: TGNA
# Get data for: TGT
# Get data for: TGTX
# Get data for: TH
# Get data for: THC
# Get data for: THFF
# Get data for: THG
# Get data for: THO
# Get data for: THR
# Get data for: THRM
# Get data for: THS
# Get data for: TIF
# Get data for: TILE
# Get data for: TIPT
# Get data for: TISI
# Get data for: TITN
# Get data for: TJX
# Get data for: TKR
# Get data for: TLF
# Get data for: TLGT
# Couldn't get data for: TLGT
# Get data for: TLYS
# Get data for: TMDX
# Get data for: TMHC
# Get data for: TMO
# Get data for: TMP
# Get data for: TMST
# Get data for: TMUS
# Get data for: TNAV
# Get data for: TNC
# Get data for: TNDM
# Get data for: TNET
# Get data for: TNXP
# Get data for: TOL
# Get data for: TOWN
# Get data for: TPB
# Get data for: TPC
# Get data for: TPCO
# Get data for: TPH
# Get data for: TPHS
# Get data for: TPIC
# Get data for: TPR
# Get data for: TPTX
# Get data for: TPX
# Get data for: TR
# Get data for: TRC
# Get data for: TRCH
# Get data for: TREC
# Get data for: TREE
# Get data for: TREX
# Get data for: TRGP
# Get data for: TRHC
# Get data for: TRIP
# Get data for: TRMB
# Get data for: TRMK
# Get data for: TRN
# Get data for: TRNO
# Get data for: TRNS
# Get data for: TROW
# Get data for: TROX
# Get data for: TRS
# Get data for: TRST
# Get data for: TRT
# Get data for: TRTN
# Get data for: TRTX
# Get data for: TRU
# Get data for: TRUP
# Get data for: TRV
# Get data for: TRVN
# Get data for: TRXC
# Get data for: TSBK
# Get data for: TSC
# Couldn't get data for: TSC
# Get data for: TSCO
# Get data for: TSE
# Get data for: TSLA
# Get data for: TSN
# Get data for: TSQ
# Get data for: TTC
# Get data for: TTD
# Get data for: TTEC
# Get data for: TTEK
# Get data for: TTGT
# Get data for: TTI
# Get data for: TTMI
# Get data for: TTNP
# Get data for: TTOO
# Get data for: TTS
# Get data for: TTWO
# Get data for: TUP
# Get data for: TUSK
# Get data for: TVTY
# Get data for: TW
# Get data for: TWI
# Get data for: TWIN
# Get data for: TWLO
# Get data for: TWNK
# Get data for: TWO
# Get data for: TWOU
# Get data for: TWST
# Get data for: TWTR
# Get data for: TXMD
# Get data for: TXN
# Get data for: TXRH
# Get data for: TXT
# Get data for: TYL
# Get data for: TYME
# Get data for: TZOO
# Get data for: UA
# Get data for: UAA
# Get data for: UAL
# Get data for: UAMY
# Get data for: UBA
# Get data for: UBCP
# Get data for: UBER
# Get data for: UBFO
# Get data for: UBOH
# Get data for: UBSI
# Get data for: UCBI
# Get data for: UCTT
# Get data for: UDR
# Get data for: UE
# Get data for: UEC
# Get data for: UEIC
# Get data for: UFAB
# Get data for: UFCS
# Get data for: UFI
# Get data for: UFPI
# Get data for: UFPT
# Get data for: UFS
# Get data for: UG
# Get data for: UGI
# Get data for: UHAL
# Get data for: UHS
# Get data for: UHT
# Get data for: UI
# Get data for: UIHC
# Get data for: UIS
# Get data for: ULBI
# Get data for: ULH
# Get data for: ULTA
# Get data for: UMBF
# Get data for: UMH
# Get data for: UMPQ
# Get data for: UNAM
# Get data for: UNB
# Get data for: UNF
# Get data for: UNFI
# Get data for: UNH
# Get data for: UNIT
# Get data for: UNM
# Get data for: UNP
# Get data for: UNTY
# Get data for: UNVR
# Get data for: UONE
# Get data for: UONEK
# Get data for: UPLD
# Get data for: UPS
# Get data for: UPWK
# Get data for: URBN
# Get data for: URI
# Get data for: UROV
# Get data for: USAK
# Get data for: USAP
# Get data for: USAT
# Get data for: USB
# Get data for: USCR
# Get data for: USD
# Get data for: USEG
# Get data for: USFD
# Get data for: USIO
# Get data for: USLM
# Get data for: USM
# Get data for: USNA
# Get data for: USPH
# Get data for: USWS
# Get data for: USX
# Get data for: UTHR
# Get data for: UTI
# Get data for: UTL
# Get data for: UTMD
# Get data for: UUU
# Get data for: UVE
# Get data for: UVSP
# Get data for: UVV
# Get data for: V
# Get data for: VAC
# Get data for: VAL
# Get data for: VALU
# Get data for: VAPO
# Get data for: VAR
# Couldn't get data for: VAR
# Get data for: VBFC
# Get data for: VBIV
# Get data for: VBTX
# Get data for: VC
# Get data for: VCEL
# Get data for: VCRA
# Get data for: VCTR
# Couldn't get data for: VCTR
# Get data for: VCYT
# Get data for: VEC
# Couldn't get data for: VEC
# Get data for: VECO
# Get data for: VEEV
# Get data for: VER
# Get data for: VERI
# Get data for: VERU
# Get data for: VFC
# Get data for: VG
# Get data for: VGR
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI',
#  'CBB',
#  'CBTX',
#  'CDEV',
#  'CDR',
#  'CECE',
#  'CLBS',
#  'CLR',
#  'CLSN',
#  'CLVS',
#  'CMD',
#  'CMO',
#  'CNR',
#  'COG',
#  'CRDB',
#  'CTT',
#  'CXO',
#  'CYTR',
#  'DRE',
#  'ELY',
#  'EYEG',
#  'EYES',
#  'FB',
#  'FBHS',
#  'FFG',
#  'FNHC',
#  'FRAN',
#  'GBL',
#  'GEFB',
#  'GFN',
#  'GRBK',
#  'GTT',
#  'GWGH',
#  'HEIA',
#  'HIL',
#  'HPR',
#  'HTA',
#  'HTBX',
#  'IEC',
#  'IIVI',
#  'INS',
#  'IO',
#  'JCS',
#  'KIN',
#  'LB',
#  'LENB',
#  'LGFB',
#  'LJPC',
#  'LLNW',
#  'LNDC',
#  'MDLY',
#  'MDP',
#  'MLHR',
#  'NAV',
#  'NBEV',
#  'NETE',
#  'NRZ',
#  'NXTD',
#  'ODT',
#  'OMED',
#  'PEI',
#  'REV',
#  'RVI',
#  'SCON',
#  'SQBG',
#  'SWM',
#  'SYN',
#  'SYNL',
#  'TBK',
#  'TCF',
#  'TCO',
#  'TLGT',
#  'TSC',
#  'VAR',
#  'VCTR',
#  'VEC']

# %%
for x in range(3000, 3218):
    save_shares_data_to_csv(folder, tickers[x])
print("Finished")
shares_not_downloaded
# Out:
# Get data for: VHC
# Get data for: VIA
# Get data for: VIAV
# Get data for: VICI
# Get data for: VICR
# Get data for: VIRC
# Get data for: VIRT
# Get data for: VISL
# Get data for: VIVO
# Get data for: VKTX
# Get data for: VLGEA
# Get data for: VLO
# Get data for: VLY
# Get data for: VMC
# Get data for: VMI
# Get data for: VMW
# Get data for: VNCE
# Get data for: VNDA
# Get data for: VNE
# Get data for: VNO
# Get data for: VNRX
# Get data for: VNTR
# Get data for: VOXX
# Get data for: VOYA
# Get data for: VPG
# Get data for: VRA
# Get data for: VRAY
# Get data for: VREX
# Get data for: VRNS
# Get data for: VRNT
# Get data for: VRRM
# Get data for: VRS
# Couldn't get data for: VRS
# Get data for: VRSK
# Get data for: VRSN
# Get data for: VRTS
# Get data for: VRTU
# Get data for: VRTV
# Get data for: VRTX
# Get data for: VSAT
# Get data for: VSEC
# Get data for: VSH
# Get data for: VST
# Get data for: VSTM
# Get data for: VSTO
# Get data for: VTNR
# Get data for: VTR
# Get data for: VTVT
# Get data for: VUZI
# Get data for: VVI
# Get data for: VVV
# Get data for: VXRT
# Get data for: VYGR
# Get data for: VZ
# Get data for: W
# Get data for: WAB
# Get data for: WABC
# Get data for: WAFD
# Get data for: WAL
# Get data for: WASH
# Get data for: WAT
# Get data for: WATT
# Get data for: WBA
# Get data for: WBS
# Get data for: WBT
# Couldn't get data for: WBT
# Get data for: WCC
# Get data for: WD
# Get data for: WDAY
# Get data for: WDC
# Get data for: WDFC
# Get data for: WDR
# Get data for: WEC
# Get data for: WELL
# Get data for: WEN
# Get data for: WERN
# Get data for: WETF
# Get data for: WEX
# Get data for: WEYS
# Get data for: WFC
# Get data for: WGO
# Get data for: WH
# Get data for: WHD
# Get data for: WHG
# Get data for: WHLM
# Get data for: WHLR
# Get data for: WHR
# Get data for: WIFI
# Get data for: WINA
# Get data for: WING
# Get data for: WIRE
# Get data for: WK
# Get data for: WKHS
# Get data for: WLDN
# Get data for: WLFC
# Get data for: WLK
# Get data for: WLL
# Get data for: WM
# Get data for: WMB
# Get data for: WMC
# Get data for: WMK
# Get data for: WMS
# Get data for: WMT
# Get data for: WNC
# Get data for: WNEB
# Get data for: WOR
# Get data for: WOW
# Get data for: WPC
# Get data for: WPG
# Couldn't get data for: WPG
# Get data for: WPX
# Get data for: WRB
# Get data for: WRE
# Couldn't get data for: WRE
# Get data for: WRI
# Get data for: WRK
# Get data for: WRLD
# Get data for: WRTC
# Get data for: WSBC
# Get data for: WSBF
# Get data for: WSC
# Get data for: WSFS
# Get data for: WSM
# Get data for: WSO
# Get data for: WSR
# Get data for: WST
# Get data for: WSTG
# Couldn't get data for: WSTG
# Get data for: WSTL
# Get data for: WTBA
# Get data for: WTER
# Get data for: WTFC
# Get data for: WTI
# Get data for: WTM
# Get data for: WTRH
# Get data for: WTS
# Get data for: WTT
# Get data for: WTTR
# Get data for: WU
# Get data for: WVE
# Get data for: WVFC
# Get data for: WVVI
# Get data for: WW
# Get data for: WWD
# Get data for: WWE
# Get data for: WWR
# Get data for: WWW
# Get data for: WY
# Get data for: WYNN
# Get data for: WYY
# Get data for: X
# Get data for: XBIT
# Get data for: XEC
# Get data for: XEL
# Get data for: XELA
# Get data for: XELB
# Get data for: XENT
# Get data for: XERS
# Get data for: XFOR
# Get data for: XHR
# Get data for: XLNX
# Get data for: XLRN
# Get data for: XNCR
# Get data for: XOG
# Get data for: XOM
# Get data for: XOMA
# Get data for: XONE
# Get data for: XPER
# Get data for: XPL
# Get data for: XPO
# Get data for: XRAY
# Get data for: XRX
# Get data for: XSPA
# Couldn't get data for: XSPA
# Get data for: XTNT
# Get data for: XXII
# Get data for: XYL
# Get data for: Y
# Get data for: YELP
# Get data for: YETI
# Get data for: YEXT
# Get data for: YMAB
# Get data for: YORW
# Get data for: YTEN
# Get data for: YUM
# Get data for: Z
# Get data for: ZAGG
# Get data for: ZBH
# Get data for: ZBRA
# Get data for: ZDGE
# Get data for: ZEN
# Get data for: ZEUS
# Get data for: ZG
# Get data for: ZGNX
# Get data for: ZION
# Get data for: ZIOP
# Couldn't get data for: ZIOP
# Get data for: ZIXI
# Get data for: ZM
# Get data for: ZNGA
# Get data for: ZS
# Couldn't get data for: ZS
# Get data for: ZSAN
# Get data for: ZTS
# Get data for: ZUMZ
# Get data for: ZUO
# Get data for: ZVO
# Get data for: ZYNE
# Get data for: ZYXI
# Get data for: TRUE
# Get data for: BRMK
# Get data for: CRT
# Get data for: DREUF
# Get data for: GAIN
# Get data for: GLAD
# Get data for: HCAP
# Get data for: HRZN
# Get data for: MAIN
# Get data for: OXSQ
# Get data for: PBA
# Get data for: PBT
# Get data for: PFLT
# Get data for: PRT
# Get data for: PSEC
# Get data for: SBR
# Get data for: SUNS
# Finished
# ['AFI',
#  'AGMA',
#  'AHC',
#  'ALNA',
#  'ANIX',
#  'ANTM',
#  'ARA',
#  'BFB',
#  'BLL',
#  'BOMN',
#  'BRG',
#  'CAI',
#  'CBB',
#  'CBTX',
#  'CDEV',
#  'CDR',
#  'CECE',
#  'CLBS',
#  'CLR',
#  'CLSN',
#  'CLVS',
#  'CMD',
#  'CMO',
#  'CNR',
#  'COG',
#  'CRDB',
#  'CTT',
#  'CXO',
#  'CYTR',
#  'DRE',
#  'ELY',
#  'EYEG',
#  'EYES',
#  'FB',
#  'FBHS',
#  'FFG',
#  'FNHC',
#  'FRAN',
#  'GBL',
#  'GEFB',
#  'GFN',
#  'GRBK',
#  'GTT',
#  'GWGH',
#  'HEIA',
#  'HIL',
#  'HPR',
#  'HTA',
#  'HTBX',
#  'IEC',
#  'IIVI',
#  'INS',
#  'IO',
#  'JCS',
#  'KIN',
#  'LB',
#  'LENB',
#  'LGFB',
#  'LJPC',
#  'LLNW',
#  'LNDC',
#  'MDLY',
#  'MDP',
#  'MLHR',
#  'NAV',
#  'NBEV',
#  'NETE',
#  'NRZ',
#  'NXTD',
#  'ODT',
#  'OMED',
#  'PEI',
#  'REV',
#  'RVI',
#  'SCON',
#  'SQBG',
#  'SWM',
#  'SYN',
#  'SYNL',
#  'TBK',
#  'TCF',
#  'TCO',
#  'TLGT',
#  'TSC',
#  'VAR',
#  'VCTR',
#  'VEC',
#  'VRS',
#  'WBT',
#  'WPG',
#  'WRE',
#  'WSTG',
#  'XSPA',
#  'ZIOP',
#  'ZS']

# %%
# copy shares that didn't download into a master block "missing_shares" 
missing_shares = shares_not_downloaded.copy()

# %%
# run download for shares that didn't download the first time around. 
for x in missing_shares:
    save_shares_data_to_csv(folder, x)
print("Finished")

# %% [markdown]
# #### Function to Download individual share data

# %%
def save_individual_share_to_csv(ticker):
    api_call = TimeSeries(key, output_format='pandas') 
    df = api_call.get_daily_adjusted(ticker, outputsize='full') 
    df[0].to_csv(r"C:/Users/User/Documents/PM Tools/US Share Market Data/Wilshire5000/" + ticker + ".csv")
    
    return df

# %%
META = save_individual_share_to_csv('META')

# %%
META
# Out:
# (            1. open  2. high    3. low  4. close  5. adjusted close  \
#  date
#  2022-12-28   116.25  118.150  115.5100  115.6200           115.6200
#  2022-12-27   117.93  118.600  116.0501  116.8800           116.8800
#  2022-12-23   116.03  118.175  115.5350  118.0400           118.0400
#  2022-12-22   117.20  118.620  114.3800  117.1200           117.1200
#  2022-12-21   116.70  120.340  115.6200  119.7600           119.7600
#  ...             ...      ...       ...       ...                ...
#  2012-05-24    32.95   33.210   31.7700   33.0300            33.0300
#  2012-05-23    31.37   32.500   31.3600   32.0000            32.0000
#  2012-05-22    32.61   33.590   30.9400   31.0000            31.0000
#  2012-05-21    36.53   36.660   33.0000   34.0300            34.0300
#  2012-05-18    42.05   45.000   38.0000   38.2318            38.2318
#
#                6. volume  7. dividend amount  8. split coefficient
#  date
#  2022-12-28   19612473.0                 0.0                   1.0
#  2022-12-27   21392311.0                 0.0                   1.0
#  2022-12-23   17796625.0                 0.0                   1.0
#  2022-12-22   23618121.0                 0.0                   1.0
#  2022-12-21   20392799.0                 0.0                   1.0
#  ...                 ...                 ...                   ...
#  2012-05-24   50237200.0                 0.0                   1.0
#  2012-05-23   73600000.0                 0.0                   1.0
#  2012-05-22  101786600.0                 0.0                   1.0
#  2012-05-21  168192700.0                 0.0                   1.0
#  2012-05-18  573576400.0                 0.0                   1.0
#
#  [2671 rows x 8 columns],
#  {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'META',
#   '3. Last Refreshed': '2022-12-28',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'})
